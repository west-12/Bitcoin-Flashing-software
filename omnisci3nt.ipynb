# %% [markdown]
# # 🔍 Omnisci3nt - Web Recon CLI Tool
#
# **Install and use Omnisci3nt right here in Colab or Jupyter.**

# %%
# 📦 Clone the repo and install dependencies
# !git clone https://github.com/spyboy-productions/omnisci3nt.git
# %cd omnisci3nt
# !pip3 install -r requirements.txt

# %%
# 📘 Show command help
# !python3 -m omnisci3nt.omnisci3nt -h

# %% [markdown]
# ## ✅ Example Usage

# %%
# 🔍 Run All recon on example.com
# !python3 -m omnisci3nt.omnisci3nt -all example.com
# Out:
#
#                       .__              .__________         __
#   ____   _____   ____ |__| ______ ____ |__\_____  \  _____/  |_
#  /  _ \ /     \ /    \|  |/  ___// ___\|  | _(__  < /    \   __\
# (  <_> )  Y Y  \   |  \  |\___ \\  \___|  |/       \   |  \  |
#  \____/|__|_|  /___|  /__/____  >\___  >__/______  /___|  /__|
#              \/     \/        \/     \/          \/     \/
#     Unveiling the Hidden Layers of the Web.
#
#
# └➤ Version      : 1.0.5
# └➤ Creator      : Spyboy
# └➤ Twitter      : https://spyboy.in/twitter
# └➤ Discord      : https://spyboy.in/Discord
# └➤ Github       : https://github.com/spyboy-productions/omnisci3nt
#
# ____________________________________________________________________________
#
# Target: example.com
#
# [✓] Valid target. Proceeding with reconnaissance...
#
#     +-+-+-+-+-+ +-+-+-+-+-+-+-+
#     |R|e|c|o|n| |S|t|a|r|t|e|d|
#     +-+-+-+-+-+ +-+-+-+-+-+-+-+
#
# Running all reconnaissance modules for example.com
#
# [~] IP lookup : example.com
#
# [+] IP: 2606:4700:10::6814:179a
# [+] continent: North America
# [+] continent code: NA
# [+] country: Canada
# [+] country code: CA
# [+] region name: Ontario
# [+] region: ON
# [+] city: Toronto
# [+] district:
# [+] zip: M5A
# [+] timezone: America/Toronto
# [+] name: CLOUDFLARENET
# [+] org: Cloudflare, Inc.
# [+] as: AS13335 Cloudflare, Inc.
# [+] isp: Cloudflare, Inc.
# [+] reverse:
# [+] offset: -14400
# [+] currency: CAD
# [+] proxy: False
# [+] hosting: True
# [+] mobile: False
# [+] latitude: 43.6532
# [+] longitude: -79.3832
#
# [~] Headers :
#
# [+] Date: Thu, 02 Jul 2026 05:24:34 GMT
# [+] Content-Type: text/html
# [+] Transfer-Encoding: chunked
# [+] Connection: keep-alive
# [+] Server: cloudflare
# [+] last-modified: Wed, 01 Jul 2026 17:52:37 GMT
# [+] allow: GET, HEAD
# [+] Age: 13223
# [+] cf-cache-status: HIT
# [+] Content-Encoding: br
# [+] CF-RAY: a14b399148516b60-TPE
#
# [~] Whois :
#
# {
#   "domain_name": "EXAMPLE.COM",
#   "registrar": "RESERVED-Internet Assigned Numbers Authority",
#   "registrar_url": "http://res-dom.iana.org",
#   "reseller": null,
#   "whois_server": "whois.iana.org",
#   "referral_url": null,
#   "updated_date": "2026-01-16 18:26:50+00:00",
#   "creation_date": "1995-08-14 04:00:00+00:00",
#   "expiration_date": "2026-08-13 04:00:00+00:00",
#   "name_servers": [
#     "ELLIOTT.NS.CLOUDFLARE.COM",
#     "HERA.NS.CLOUDFLARE.COM"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited"
#   ],
#   "emails": null,
#   "dnssec": "signedDelegation",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "registrant_postal_code": null,
#   "country": null,
#   "tech_name": null,
#   "tech_org": null,
#   "admin_name": null,
#   "admin_org": null
# }
#
# [~] SSL Certificate Information  :
#
# [+] Subject: {'commonName': 'example.com'}
# [+] Issuer: {'countryName': 'US', 'organizationName': 'SSL Corporation', 'commonName': 'Cloudflare TLS Issuing ECC CA 3'}
# [+] Valid From: May 31 21:39:12 2026 GMT
# [+] Valid Until: Aug 29 21:41:26 2026 GMT
# [+] IP Address: 104.20.23.154
#
# [~] Starting DNS Enumeration...
#
# [+] A: 104.20.23.154
# [+] A: 172.66.147.243
# [+] AAAA: 2606:4700:10::6814:179a
# [+] AAAA: 2606:4700:10::ac42:93f3
# [+] MX: 0 .
# [+] NS: hera.ns.cloudflare.com.
# [+] NS: elliott.ns.cloudflare.com.
# [+] TXT: "v=spf1 -all"
# [+] TXT: "_k2n1y4vw3qtb4skdx9e7dxt97qrmmq9"
# [+] DMARC: "v=DMARC1;p=reject;sp=reject;adkim=s;aspf=s"
#
# [~] Reverse DNS :
#
# ['chromer.00.example.com,103.136.70.82',
#  '0001.example.com,103.102.230.52',
#  'damping.dutiful.01.example.com,5.181.27.241',
#  'yangfan2.tec.02.example.com,45.80.215.222',
#  'yangfan3.tec.02.example.com,5.8.33.119',
#  'yangfan4.tec.02.example.com,5.8.33.177',
#  'test-vlad-17.03.example.com,46.173.214.12',
#  'valya.starchenko.04.example.com,46.8.53.209',
#  'd.g.0455737.example.com,5.188.38.35',
#  'shura.garaev.06.example.com,193.164.17.191',
#  'sowa.07.example.com,185.204.2.39',
#  'doctor.09.example.com,192.162.246.232',
#  'doctor1.09.example.com,192.162.247.10',
#  'doctor3.09.example.com,192.162.246.31',
#  'doctor5.09.example.com,192.162.247.239',
#  'citrons.mask.0m.example.com,5.45.184.90',
#  'curious-scarier1.0o.example.com,212.80.218.161',
#  '1.example.com,83.14.191.103',
#  '46.8.52.1.example.com,46.8.52.9',
#  'briz667.1.example.com,108.165.235.20',
#  '11.example.com,5.188.224.213',
#  'ivan.platonov.11.example.com,91.235.136.108',
#  '110711.example.com,195.123.208.128',
#  'black.coder.112.example.com,195.22.149.29',
#  '45.14.247.117.example.com,45.14.247.117',
#  '120113.example.com,195.123.233.70',
#  '1207.example.com,185.224.212.55',
#  '1270011721.example.com,212.80.217.188',
#  '12758xz-vpn.example.com,185.147.81.188',
#  'ross.ball.128.example.com,192.162.247.73',
#  '133175.example.com,185.14.30.2',
#  '134330.example.com,195.123.212.105',
#  'a2.kreiber.1369.example.com,103.136.70.4',
#  '139520.example.com,82.118.22.95',
#  '14----apr----rrdd.example.com,5.181.77.143',
#  'slfarma1.14.example.com,109.248.7.36',
#  'sandra.wilson.156.example.com,192.162.247.37',
#  '159322.example.com,195.123.222.228',
#  '16.example.com,5.188.224.246',
#  'reynard.sherman.163.example.com,192.162.246.3',
#  '163986.example.com,195.123.209.104',
#  '164249.example.com,5.34.177.179',
#  '165756.example.com,195.123.220.114',
#  'mamad.155.166.example.com,103.215.218.40',
#  '172388.example.com,195.123.212.162',
#  '174123.example.com,195.123.245.151',
#  '174143.example.com,185.82.219.132',
#  '174162.example.com,195.123.246.193',
#  '174327.example.com,185.14.30.150',
#  '174332.example.com,185.14.30.249',
#  '174342.example.com,82.118.22.85',
#  '174347.example.com,82.118.22.209',
#  '175122.example.com,195.123.219.218',
#  '175440.example.com,195.123.245.6',
#  '175454.example.com,82.118.22.24',
#  '176123.example.com,5.34.180.218',
#  '176953.example.com,185.14.31.74',
#  '176958.example.com,185.14.31.165',
#  '177671.example.com,82.118.21.11',
#  '177676.example.com,195.123.246.240',
#  '178774.example.com,195.123.245.117',
#  'maxim.malyshev.18.example.com,45.91.52.160',
#  '180020.example.com,185.82.218.235',
#  '180651.example.com,185.14.29.31',
#  '181598.example.com,195.123.216.62',
#  '181613.example.com,195.123.244.217',
#  '182075.example.com,82.118.21.15',
#  '182080.example.com,195.123.244.238',
#  '182182.example.com,185.14.28.77',
#  '182226.example.com,195.123.208.165',
#  '183044.example.com,185.204.0.52',
#  '183097.example.com,5.34.180.177',
#  '183260.example.com,185.14.28.105',
#  '184306.example.com,5.34.182.147',
#  '184377.example.com,195.123.244.153',
#  '184397.example.com,5.34.180.68',
#  '184466.example.com,5.34.180.6',
#  '184481.example.com,195.123.208.119',
#  '184486.example.com,195.123.208.134',
#  '184559.example.com,185.14.28.196',
#  '184661.example.com,185.14.28.201',
#  '185565.example.com,5.34.182.36',
#  '185768.example.com,195.123.209.12',
#  '186174.example.com,5.34.176.90',
#  '187194.example.com,195.123.211.41',
#  '188.example.com,185.224.212.28',
#  '188068.example.com,195.123.217.70',
#  '188441.example.com,45.90.59.247',
#  '189061.example.com,195.123.217.75',
#  '189160.example.com,195.123.225.170',
#  '18917.example.com,195.123.245.220',
#  '18923.example.com,195.123.209.252',
#  '189337.example.com,195.123.217.57',
#  '189396.example.com,195.123.219.44',
#  '189402.example.com,195.123.219.51',
#  '189408.example.com,62.233.57.55',
#  '189441.example.com,195.123.219.55',
#  '189702.example.com,217.12.206.72',
#  '189735.example.com,195.123.217.177',
#  '189794.example.com,195.123.218.226',
#  '189812.example.com,195.123.211.47',
#  '18x96x50x110.example.com,110.50.96.18',
#  '190189.example.com,62.233.57.145',
#  '190400.example.com,5.34.176.133',
#  '190406.example.com,195.123.218.73',
#  '191126.example.com,62.233.57.63',
#  '191132.example.com,195.123.210.204',
#  '191138.example.com,195.123.210.214',
#  '191237.example.com,5.34.176.244',
#  '191261.example.com,217.12.207.78',
#  '191391.example.com,217.12.206.87',
#  '191498.example.com,195.123.218.116',
#  '191529.example.com,217.12.207.180',
#  '191567.example.com,195.123.217.166',
#  '191617.example.com,217.12.206.201',
#  '191718.example.com,195.123.210.170',
#  '191754.example.com,195.123.211.219',
#  '45.150.239.192.example.com,45.150.239.192',
#  '192130.example.com,5.34.176.45',
#  '192216.example.com,195.123.219.16',
#  '192575.example.com,195.123.218.72',
#  '192602.example.com,195.123.218.95',
#  '192680.example.com,195.123.219.107',
#  '192704.example.com,195.123.210.157',
#  '192710.example.com,195.123.210.159',
#  '192716.example.com,195.123.210.187',
#  '192845.example.com,62.233.57.102',
#  '193045.example.com,195.123.212.51',
#  '193219.example.com,195.123.224.198',
#  '193225.example.com,62.233.57.35',
#  '193685.example.com,195.123.212.212',
#  '193697.example.com,195.123.212.217',
#  '193745.example.com,62.233.57.57',
#  '193794.example.com,5.34.182.179',
#  '193970.example.com,217.12.206.166',
#  '193976.example.com,217.12.207.31',
#  '194.example.com,195.140.144.194',
#  '194009.example.com,62.233.57.173',
#  '194021.example.com,217.12.207.149',
#  '194255.example.com,185.14.30.166',
#  '194423.example.com,185.14.30.230',
#  '195.example.com,195.140.144.195',
#  '195-234-63-10.example.com,195.234.63.10',
#  '195-234-63-6.example.com,195.234.63.6',
#  '195-234-63-7.example.com,195.234.63.7',
#  'b.samuels.1968583.example.com,45.150.239.86',
#  'dimitry.1969.example.com,212.80.218.178',
#  '196916.example.com,195.123.219.173',
#  '197183.example.com,45.90.59.85',
#  '197716.example.com,82.118.21.252',
#  'denis1.ryzhov.1979.example.com,195.22.152.63',
#  'denis2.ryzhov.1979.example.com,45.143.139.4',
#  '198477.example.com,5.34.182.68',
#  'invest.1990.example.com,185.31.160.68',
#  '199498.example.com,195.123.218.178',
#  'elena.belova.1995.example.com,82.146.51.102',
#  'dmitry.1997.example.com,91.235.136.39',
#  '199784.example.com,195.123.217.82',
#  'lexa.bob.1999.example.com,212.80.218.240',
#  'maxaoh.forever.1999.example.com,45.151.182.177',
#  'wateryelitism.1q.example.com,45.91.54.27',
#  '2.example.com,185.81.128.154',
#  'egorov.denis.2000.example.com,92.38.128.97',
#  '200126dev.example.com,209.42.26.27',
#  'yegor.varlamov.2006.example.com,5.188.39.28',
#  'gostynin.2007.example.com,5.188.37.139',
#  'tristondup.2008.example.com,46.8.209.206',
#  'tristondup1.2008.example.com,46.8.209.207',
#  'tristondup2.2008.example.com,46.8.209.208',
#  'amant.2012.example.com,91.235.137.22',
#  'ulezko1.2015.example.com,212.80.216.233',
#  'brianna.marshman.2020.example.com,45.150.239.125',
#  '202003.example.com,195.123.210.174',
#  '206712.example.com,45.90.58.5',
#  'digitalden.21.example.com,89.223.91.16',
#  'digitalden1.21.example.com,5.188.190.228',
#  'a.efimov.21.example.com,82.202.163.0',
#  'a1.efimov.21.example.com,62.173.152.196',
#  '210489.example.com,82.118.16.171',
#  '210503.example.com,82.118.16.212',
#  '210617.example.com,195.123.224.181',
#  '211002.example.com,195.123.242.5',
#  '211130.example.com,195.123.220.192',
#  '211223.example.com,5.34.176.87',
#  '211229.example.com,5.34.176.143',
#  '211235.example.com,195.123.218.44',
#  '211241.example.com,195.123.218.94',
#  '211247.example.com,195.123.217.99',
#  '211269.example.com,195.123.220.162',
#  '211287.example.com,195.123.220.201',
#  '211293.example.com,195.123.220.202',
#  '211299.example.com,195.123.220.203',
#  '211323.example.com,195.123.217.51',
#  '211335.example.com,195.123.219.3',
#  '211722.example.com,195.123.219.131',
#  '211728.example.com,46.28.70.120',
#  '212069.example.com,193.238.152.20',
#  '213538.example.com,195.123.209.71',
#  '213692.example.com,62.233.57.69',
#  '214922.example.com,85.90.197.177',
#  '215643.example.com,46.28.64.239',
#  '215800.example.com,195.123.224.61',
#  '21588.example.com,82.118.22.100',
#  '215890.example.com,195.123.209.129',
#  '215932.example.com,195.123.220.52',
#  '216028.example.com,195.123.213.223',
#  '216097.example.com,195.123.220.94',
#  '216139.example.com,5.34.178.208',
#  '216181.example.com,193.238.152.163',
#  '216193.example.com,195.123.220.144',
#  '216262.example.com,193.238.152.167',
#  '216323.example.com,45.90.59.18',
#  '216329.example.com,195.123.219.139',
#  '216449.example.com,195.123.220.251',
#  '216491.example.com,46.28.64.182',
#  '216517.example.com,193.238.152.68',
#  '216607.example.com,193.238.152.144',
#  '216637.example.com,195.123.218.74',
#  '216685.example.com,195.123.233.198',
#  '216769.example.com,185.82.217.76',
#  '216782.example.com,195.123.209.248',
#  '216824.example.com,195.123.216.208',
#  '21810.example.com,5.34.183.219',
#  'liguohui1.219.example.com,89.44.196.92',
#  '228.example.com,185.104.248.228',
#  'nest1.23a.example.com,92.38.128.224',
#  '87.251.73.248.example.com,87.251.73.248',
#  'richesse.25.example.com,195.22.153.11',
#  '26650.example.com,195.123.244.135',
#  '27226.example.com,195.123.220.17',
#  'vova232.28.example.com,45.81.32.34',
#  '280126v7.example.com,209.42.26.43',
#  '28194.example.com,45.90.57.42',
#  '2906402ua.example.com,91.210.191.209',
#  '2906402ua13.example.com,91.210.191.174',
#  '2906402ua14.example.com,91.210.191.170',
#  '2906402ua16.example.com,91.210.191.249',
#  '2906402ua17.example.com,91.210.191.163',
#  '2906402ua19.example.com,91.210.191.60',
#  '2906402ua20.example.com,91.210.191.59',
#  '2906402ua22.example.com,91.210.191.57',
#  '2906402ua23.example.com,91.210.191.176',
#  '2906402ua4.example.com,91.210.191.229',
#  '2906402ua8.example.com,91.210.191.89',
#  'dimu.29077.example.com,45.91.52.210',
#  '31477.example.com,195.123.219.80',
#  '31880.example.com,195.123.211.78',
#  '31954.example.com,62.233.57.161',
#  '31974.example.com,195.123.210.229',
#  '32064.example.com,195.123.233.38',
#  '3236squidsbased.example.com,95.164.53.153',
#  '3241squidsbased.example.com,95.164.53.156',
#  '32626.example.com,195.123.212.10',
#  'jason.brody.332022.example.com,185.17.121.22',
#  'stanley.ray.333.example.com,192.162.246.99',
#  '3402squidsbased.example.com,141.98.6.48',
#  '3434234.example.com,31.222.238.106',
#  '351400.example.com,185.117.116.82',
#  '3526squidsbased.example.com,95.164.53.213',
#  '3627squidsbased.example.com,141.98.6.111',
#  '3844squidsbased.example.com,93.123.39.58',
#  '4.example.com,46.8.209.224',
#  '40184.example.com,195.123.211.224',
#  '4070squidsbased.example.com,95.164.55.132',
#  '40860.example.com,195.123.225.124',
#  '40890.example.com,5.34.176.15',
#  '41118.example.com,185.14.31.90',
#  '41465.example.com,195.123.209.169',
#  '41734.example.com,82.118.16.190',
#  '41919.example.com,46.28.70.139',
#  '41931.example.com,5.34.176.151',
#  '41943.example.com,195.123.209.175',
#  '42005.example.com,85.90.197.183',
#  '42030.example.com,195.123.216.242',
#  '42090.example.com,195.123.233.158',
#  '42144.example.com,195.123.216.186',
#  '42204.example.com,5.34.176.173',
#  '42228.example.com,45.90.58.43',
#  '42240.example.com,185.82.218.178',
#  '42264.example.com,62.233.57.116',
#  '42381.example.com,193.238.152.90',
#  '42393.example.com,195.123.216.121',
#  '42399.example.com,85.90.196.49',
#  '42424.example.com,195.123.209.165',
#  '42480.example.com,46.28.64.191',
#  '42540.example.com,193.238.152.78',
#  'preston.ward.429.example.com,192.162.247.67',
#  'joshua.golden.434.example.com,192.162.247.193',
#  '4351squidsbased.example.com,95.164.53.184',
#  '4384squidsbased.example.com,141.98.6.9',
#  'ivanov.4409.example.com,185.68.93.203',
#  'ivanov1.4409.example.com,31.41.44.31',
#  'ivanov10.4409.example.com,31.41.44.111',
#  'ivanov12.4409.example.com,31.41.44.95',
#  'ivanov13.4409.example.com,31.41.44.185',
#  'ivanov14.4409.example.com,31.41.44.187',
#  'ivanov2.4409.example.com,31.41.44.23',
#  'ivanov3.4409.example.com,31.41.44.137',
#  'ivanov6.4409.example.com,31.41.44.108',
#  'ivanov7.4409.example.com,31.41.44.147',
#  'ivanov9.4409.example.com,31.41.44.82',
#  '4463squidsbased.example.com,95.164.123.151',
#  '4464squidsbased.example.com,95.164.123.152',
#  '4514squidsbased.example.com,141.98.6.65',
#  '4526squidsbased.example.com,185.238.191.9',
#  'jonah.poole.455.example.com,192.162.246.80',
#  '4560squidsbased.example.com,185.238.191.20',
#  'mark.harrison.46.example.com,45.150.239.100',
#  '4635squidsbased.example.com,95.164.55.41',
#  '4787squidsbased.example.com,95.164.55.73',
#  '4788squidsbased.example.com,95.164.55.74',
#  '4790squidsbased.example.com,95.164.55.77',
#  '4791squidsbased.example.com,95.164.55.78',
#  '4792squidsbased.example.com,95.164.55.79',
#  '4793squidsbased.example.com,95.164.55.81',
#  'vlasov98.48.example.com,91.235.137.64',
#  '4804squidsbased.example.com,93.123.39.45',
#  '4993squidsbased.example.com,95.164.123.96',
#  '4995060356.example.com,185.195.25.210',
#  'sychev.4ndreyka.example.com,5.188.3.141',
#  '4r4929.example.com,92.223.109.88',
#  '5.example.com,46.8.209.215',
#  'static.1.102.78.5.example.com,5.78.102.1',
#  '5029squidsbased.example.com,95.164.123.149',
#  '5031squidsbased.example.com,93.123.39.38',
#  'coral.maxwell.504.example.com,192.162.247.190',
#  'petr.efim.51.example.com,31.41.44.80',
#  '5182squidsbased.example.com,93.123.39.166',
#  '5195squidsbased.example.com,95.164.123.175',
#  '5200squidsbased.example.com,93.123.39.86',
#  '5220squidsbased.example.com,93.123.39.93',
#  '5252squidsbased.example.com,95.164.55.76',
#  '5278squidsbased.example.com,95.164.123.203',
#  '5301squidsbased.example.com,178.17.59.112',
#  '5341squidsbased.example.com,95.164.123.239',
#  '5362squidsbased.example.com,95.164.123.92',
#  '5384squidsbased.example.com,95.164.55.125',
#  '5463squidsbased.example.com,93.123.39.133',
#  '5488squidsbased.example.com,185.238.191.77',
#  '55.example.com,92.223.85.49',
#  '5521squidsbased.example.com,185.238.191.86',
#  '5553squidsbased.example.com,178.17.59.23',
#  '5618squidsbased.example.com,95.164.123.126',
#  '5706squidsbased.example.com,95.164.53.148',
#  '5723squidsbased.example.com,95.164.53.152',
#  '5729squidsbased.example.com,178.17.59.91',
#  '5738squidsbased.example.com,95.164.55.224',
#  '5864squidsbased.example.com,95.164.123.78',
#  '5867squidsbased.example.com,95.164.123.213',
#  '5873squidsbased.example.com,95.164.123.232',
#  '5881squidsbased.example.com,95.164.123.74',
#  '5890squidsbased.example.com,95.164.123.246',
#  '5921squidsbased.example.com,185.238.191.34',
#  '6010squidsbased.example.com,150.241.124.143',
#  '6016squidsbased.example.com,178.17.59.114',
#  '6018squidsbased.example.com,150.241.124.158',
#  '6020squidsbased.example.com,78.40.209.4',
#  '6022squidsbased.example.com,178.17.59.118',
#  '6068squidsbased.example.com,178.17.59.14',
#  'kylie.roger.61.example.com,45.150.239.122',
#  '6127squidsbased.example.com,93.123.39.188',
#  '6425squidsbased.example.com,103.27.157.185',
#  '6429squidsbased.example.com,93.123.39.134',
#  '6493squidsbased.example.com,103.27.157.72',
#  'hilda.williams.652.example.com,192.162.247.158',
#  'dorthy.strickland.657.example.com,192.162.247.138',
#  '6585squidsbased.example.com,95.164.123.98',
#  '6591squidsbased.example.com,103.27.157.216',
#  '6637squidsbased.example.com,178.17.59.151',
#  '6695squidsbased.example.com,178.17.59.27',
#  '6710squidsbased.example.com,89.125.48.118',
#  '6744squidsbased.example.com,89.125.48.149',
#  '6761squidsbased.example.com,150.241.124.45',
#  '6762squidsbased.example.com,150.241.124.46',
#  '6765squidsbased.example.com,178.17.59.12',
#  '6767squidsbased.example.com,93.123.39.150',
#  '6771squidsbased.example.com,93.123.39.177',
#  '6816squidsbased.example.com,185.238.191.40',
#  '6820squidsbased.example.com,95.164.123.164',
#  '6822squidsbased.example.com,103.27.157.154',
#  '6823squidsbased.example.com,103.27.157.155',
#  '6841.example.com,217.12.221.195',
#  '6889squidsbased.example.com,78.40.209.231',
#  '6897squidsbased.example.com,95.164.53.159',
#  '69.example.com,5.188.34.201',
#  '69231.example.com,83.229.14.193',
#  '6936squidsbased.example.com,89.125.48.3',
#  '6955squidsbased.example.com,178.17.59.3',
#  '6983squidsbased.example.com,178.17.59.90',
#  '6999squidsbased.example.com,178.17.59.84',
#  'martynov.aa.7012.example.com,5.188.38.96',
#  '7029squidsbased.example.com,78.40.209.64',
#  '7067squidsbased.example.com,103.27.157.141',
#  '7093squidsbased.example.com,95.164.123.38',
#  '7104squidsbased.example.com,95.164.123.24',
#  '7117squidsbased.example.com,103.27.157.231',
#  '7123squidsbased.example.com,178.17.59.101',
#  '7127squidsbased.example.com,78.40.209.65',
#  '7144squidsbased.example.com,103.27.157.8',
#  '7168squidsbased.example.com,103.27.157.115',
#  '7172squidsbased.example.com,178.17.59.70',
#  '7180squidsbased.example.com,103.27.157.130',
#  '7181squidsbased.example.com,103.27.157.134',
#  '7184squidsbased.example.com,103.27.157.183',
#  '7185squidsbased.example.com,178.17.59.11',
#  '7187.example.com,195.123.213.204',
#  '193.203.202.72.example.com,193.203.202.72',
#  '7204squidsbased.example.com,103.27.157.145',
#  '7209squidsbased.example.com,89.125.48.207',
#  '7213squidsbased.example.com,141.98.6.148',
#  '7237squidsbased.example.com,78.40.209.106',
#  '7265squidsbased.example.com,150.241.124.84',
#  '7273squidsbased.example.com,89.125.48.221',
#  '7278squidsbased.example.com,178.17.59.44',
#  '7281squidsbased.example.com,178.17.59.135',
#  '7282squidsbased.example.com,93.123.39.54',
#  '7283squidsbased.example.com,178.17.59.140',
#  '7284squidsbased.example.com,89.125.48.22',
#  '7305squidsbased.example.com,93.123.39.120',
#  '7323squidsbased.example.com,150.241.124.110',
#  'brian.bradley.733.example.com,46.8.153.2',
#  '7331squidsbased.example.com,95.164.53.110',
#  '7350squidsbased.example.com,95.164.123.1',
#  '7352squidsbased.example.com,78.40.209.153',
#  '7355squidsbased.example.com,103.27.157.3',
#  '7369squidsbased.example.com,178.17.59.98',
#  '7384squidsbased.example.com,178.17.59.89',
#  '7397squidsbased.example.com,103.27.157.200',
#  '7404squidsbased.example.com,78.40.209.238',
#  '7405squidsbased.example.com,93.123.39.34',
#  '7407squidsbased.example.com,78.40.209.242',
#  '7412squidsbased.example.com,89.125.48.105',
#  '7433squidsbased.example.com,141.98.6.199',
#  '7463squidsbased.example.com,178.17.59.166',
#  '7468squidsbased.example.com,178.17.59.169',
#  '7469squidsbased.example.com,150.241.124.235',
#  '7489squidsbased.example.com,95.164.123.60',
#  '7500squidsbased.example.com,103.27.157.160',
#  '7501squidsbased.example.com,141.98.6.182',
#  '7512squidsbased.example.com,141.98.6.38',
#  '7524squidsbased.example.com,178.17.59.52',
#  '7525squidsbased.example.com,185.238.191.12',
#  'thomas.cole.753.example.com,192.162.246.176',
#  'mikhail.kolobov.77.example.com,31.41.44.139',
#  'alex1.7721.example.com,62.173.139.240',
#  'vivat1.777.example.com,185.60.135.9',
#  'gleb.erchenko.81.example.com,46.8.52.181',
#  'shmakov.82.example.com,166.1.36.65',
#  'rabindranat.tagor.83.example.com,46.8.53.36',
#  'tonya.morozova.84.example.com,185.117.119.210',
#  'sashaf.86.example.com,86.110.208.251',
#  'kff2.88.example.com,185.180.231.212',
#  '46.8.52.89.example.com,46.8.52.89',
#  'lom.90.example.com,108.165.235.37',
#  'randommail.90.example.com,46.173.214.101',
#  'roman.markov.9090.example.com,84.252.100.21',
#  'markos.91.example.com,62.173.140.44',
#  'askkold.92.example.com,212.80.216.236',
#  'askkold1.92.example.com,45.12.6.105',
#  'makc777.92.example.com,5.188.3.142',
#  'dorothy.murphy.92.example.com,45.150.239.146',
#  'zhanna.ignatova.93.example.com,193.203.202.125',
#  'vlad.bondarev.94.example.com,5.188.37.30',
#  'vlad1.bondarev.94.example.com,5.101.218.137',
#  'kav.949.example.com,166.1.61.25',
#  'd.derrick.96242.example.com,45.91.52.165',
#  'alex041.05.9673.example.com,5.101.218.17',
#  'kimberly.conors.97.example.com,45.150.239.119',
#  'james.brown.976.example.com,192.162.247.142',
#  'dima1.123.98.example.com,91.235.136.43',
#  'frost98.98.example.com,108.165.235.61',
#  'ivan.popov.98.example.com,194.87.87.135',
#  '98m.example.com,5.188.34.66',
#  'j.fane.9930.example.com,193.164.16.124',
#  'a.example.com,83.3.97.1',
#  'a-somov.example.com,193.164.16.231',
#  'motoriko.a.a.example.com,103.136.70.59',
#  'golubeva1.a.example.com,82.202.162.197',
#  'ip.lim.a.example.com,84.252.101.231',
#  'verzakov.a.example.com,185.172.130.154',
#  'a0.example.com,45.143.139.220',
#  'a000rustemrustemov2000.example.com,103.213.249.99',
#  'a00dd49c293ccecd.example.com,91.243.86.44',
#  'a01.example.com,45.143.139.240',
#  'a016875624.example.com,45.143.139.154',
#  'a01div2.example.com,212.80.219.183',
#  'a023365.example.com,45.143.139.182',
#  'a0288992.example.com,5.188.33.40',
#  'a033366.example.com,62.173.139.127',
#  'a0333663.example.com,62.173.138.103',
#  'a0344471.example.com,146.185.196.29',
#  'a03741.example.com,45.12.6.112',
#  'a03773.example.com,5.189.223.4',
#  'a04341f22b5b6968.example.com,92.38.130.33',
#  'a05341.example.com,193.164.16.114',
#  'a06547672a1ce073.example.com,5.188.224.197',
#  'a0670bba0e06cff7.example.com,92.38.130.16',
#  'a090stas.example.com,108.165.250.18',
#  'a091293.example.com,195.22.149.208',
#  'a092876765.example.com,89.44.196.29']
#
# [~] Shared DNS :
#
# ['drrmlims.ac.in',
#  'satarasport.co.in',
#  'shantiniketantrust.in',
#  'dsowardha.co.in',
#  'cssspgcmachhra.org',
#  'samufood.com',
#  'aicdaluhera.co.in',
#  'gucl.in',
#  'bvesd.com',
#  'genaxxpublicschool.in',
#  'mbehsm.com',
#  'sncollegeoflaw.co.in',
#  'bdce.co.in',
#  'essenceinhomecare.com',
#  'agrimacassam.in',
#  'kolhapursports.co.in',
#  'zeytinlimutfak.com.tr',
#  'opakicollegebabugarh.in',
#  'bmcheindia.com',
#  'clickmymoments.com',
#  'dyds.co.in',
#  'nskwa.in',
#  'ambienceacademyjansath.in',
#  'technosofteng.in',
#  'mahadso.co.in',
#  'manthanlawcollege.in',
#  'dsojalgaon.co.in',
#  'ramsadaycollege.com',
#  'prismacloud.in',
#  'aadb.in',
#  'ndimdelhi.in',
#  'shrisaiayurvedacentre.in',
#  'ridfportal.in',
#  'sapps.cloud',
#  'nightflyer.online',
#  'theworldwidecard.net',
#  'fezztify.com',
#  'axisagroindia.in',
#  'earningcommodity.com',
#  'dsobhandara.co.in',
#  'sninstituteforeducation.in',
#  'sscpcollege.co.in',
#  'kicmohiuddinpur.co.in',
#  'dsosangli.co.in',
#  'vanasthalimrt.com',
#  'blinkbazar.com.in',
#  'bnysmindia.com',
#  'jnanpith.net',
#  'jpcollegeoflaw.co.in',
#  'woodtechfurnishing.in',
#  'stemplify.com']
#
# [+] DMARC Check for example.com
# [ok] DMARC Record Found:
# Raw Record: v=DMARC1;p=reject;sp=reject;adkim=s;aspf=s
#
# Policy Settings:
#   -> V: DMARC1
#   -> P: reject
#   -> SP: reject
#
# ==================================================
#
# [i] Created config.ini - Add your Free API keys to enable premium sources
#
# [*] Starting subdomain enumeration...
#
# [i] Checking crt.sh...
# [-] Error fetching https://crt.sh/?q=example.com: HTTPSConnectionPool(host='crt.sh', port=443): Read timed out. (read timeout=15)
#
# [-] crt.sh found nothing
#
# [i] Checking RapidDNS...
#
# [+] RapidDNS found:
#   20mail2.example.com
#   www.example.com
#
# [i] Checking AnubisDB...
# [-] AnubisDB error: Expecting value: line 1 column 1 (char 0)
#
# [i] VirusTotal skipped - Add API key to config.ini to enable
#
# [i] SecurityTrails skipped - Add API key to config.ini to enable
#
# [*] Total unique subdomains found: 2
# [!] Results saved to example.com-subdomains.txt
# [*] Completed in 23.92 seconds
#
#
# [~] Web Crawler :
#
# [+] JS Files:
#
# [+]CSS Files:
#
# [+] HTML Files:
#
# [+] PHP Files:
#
# [+] Image Files:
#
# [+] Internal Links:
#
# [+] External Links:
# https://iana.org/domains/example
#
# Failed to fetch directory. Status code: 404
#
# [+] Total JS Files: 0
# [+] Total CSS Files: 0
# [+] Total HTML Files: 0
# [+] Total PHP Files: 0
# [+] Total Image Files: 0
# [+] Total Internal Links: 0
# [+] Total External Links: 1
#
# [~] Robots & sitemap :
#
# No robots.txt file found.
#
# [~] Website build with :
#
# No programming language detected or an error occurred.
#
# [+] Website technologies:
# cdn: ['CloudFlare']
# No JavaScript libraries detected.
#
# [+] Web server: cloudflare
#
# [~] Wayback :
#
# [!] Checking Availability on Wayback Machine[..... Available ]
# [!] Fetching URLs[..... Fetching URLs ]
# [!] Fetching URLs[..... 504 ]
#
# [~] Social media links :
#
# No social media links found or an error occurred.
# No email addresses found or an error occurred.
#
# [~] Starting Directory Enumeration...
#
# [+] Threads          : 30
# [+] Timeout          : 3
# [+] Wordlist         : /content/omnisci3nt/omnisci3nt/wordlists/dirlist.txt
# [+] Allow Redirects  : False
# [+] SSL Verification : True
# [+] DNS Servers      : 1.1.1.1
# [+] Wordlist Size    : 4613
# [+] File Extensions  :
#
# Scanning: 100% 4613/4613 [00:02<00:00, 1730.70req/s]
#
# [-] No URLs found.
#
# [~] Starting Port Scan on example.com...
#
# PORT     STATE   SERVICE
# -----    ------  --------
# Scanning Ports:  85% 55509/65535 [01:52<00:13, 768.25port/s]
